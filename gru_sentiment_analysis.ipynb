# %%
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'

import numpy as np
import re

from tensorflow.keras.layers import Dense, GRU, Input, Dropout, Embedding
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.text import Tokenizer, text_to_word_sequence
from tensorflow.keras.preprocessing.sequence import pad_sequences

# %%
with open('train_data_true.txt', 'r', encoding='utf-8') as f:
    texts_true = f.readlines()
    texts_true[0] = texts_true[0].replace('\ufeff', '') #убираем первый невидимый символ

with open('train_data_false.txt', 'r', encoding='utf-8') as f:
    texts_false = f.readlines()
    texts_false[0] = texts_false[0].replace('\ufeff', '') #убираем первый невидимый символ

texts = texts_true + texts_false
count_true = len(texts_true)
count_false = len(texts_false)
total_lines = count_true + count_false
print(count_true, count_false, total_lines)


maxWordsCount = 1000
tokenizer = Tokenizer(num_words=maxWordsCount, filters='!–"—#$%&amp;()*+,-./:;<=>?@[\\]^_`{|}~\t\n\r«»', lower=True, split=' ', char_level=False)
tokenizer.fit_on_texts(texts)

dist = list(tokenizer.word_counts.items())
print(dist[:10])
print(texts[0][:100])


max_text_len = 10
data = tokenizer.texts_to_sequences(texts)
data_pad = pad_sequences(data, maxlen=max_text_len)
print(data_pad)

print( list(tokenizer.word_index.items()) )


X = data_pad
Y = np.array([[1, 0]]*count_true + [[0, 1]]*count_false)
print(X.shape, Y.shape)

indeces = np.random.choice(X.shape[0], size=X.shape[0], replace=False)
X = X[indeces]
Y = Y[indeces]


model = Sequential()
model.add(Embedding(maxWordsCount, 128, input_length = max_text_len))
model.add(GRU(128, return_sequences=True))
model.add(GRU(64))
model.add(Dense(2, activation='softmax'))
model.summary()

model.compile(loss='categorical_crossentropy', metrics=['accuracy'], optimizer=Adam(0.0001))

history = model.fit(X, Y, batch_size=32, epochs=50)

reverse_word_map = dict(map(reversed, tokenizer.word_index.items()))

def sequence_to_text(list_of_indices):
    words = [reverse_word_map.get(letter) for letter in list_of_indices]
    return(words)

# t = "Это шедевр изобразительного".lower()
t = "Я никогда не сяду за руль, это же смертельно опасно! ".lower()
data = tokenizer.texts_to_sequences([t])
data_pad = pad_sequences(data, maxlen=max_text_len)
print( sequence_to_text(data[0]) )

res = model.predict(data_pad)
print(res, np.argmax(res), sep='\n')
# Out:
# 300 300 600
# [('сегодня', 98), ('я', 403), ('с', 73), ('радостью', 5), ('отмечаю', 1), ('как', 45), ('много', 13), ('света', 4), ('и', 282), ('спокойствия', 5)]
# Сегодня я с радостью отмечаю, как много света и спокойствия приносит простая уверенность в том, что
# [[ 90   2  23 ... 199 517 200]
#  [519 759 294 ... 201  42  45]
#  [520  11 164 ...  34 765 766]
#  ...
#  [  1  33  24 ... 378  48 508]
#  [  0   0  50 ...  99   3 283]
#  [  4   9   5 ... 109  49 100]]
# [('я', 1), ('что', 2), ('и', 3), ('мне', 4), ('когда', 5), ('сегодня', 6), ('в', 7), ('день', 8), ('неприятно', 9), ('не', 10), ('с', 11), ('себе', 12), ('всё', 13), ('кажется', 14), ('меня', 15), ('на', 16), ('от', 17), ('иногда', 18), ('чувствую', 19), ('которые', 20), ('мои', 21), ('как', 22), ('каждый', 23), ('тем', 24), ('позволяю', 25), ('выбираю', 26), ('ощущаю', 27), ('даже', 28), ('нравится', 29), ('приятно', 30), ('жизнь', 31), ('устал', 32), ('разочарован', 33), ('к', 34), ('быть', 35), ('усилия', 36), ('могу', 37), ('потому', 38), ('ощущение', 39), ('это', 40), ('то', 41), ('вокруг', 42), ('мир', 43), ('за', 44), ('себя', 45), ('о', 46), ('мою', 47), ('чем', 48), ('чувство', 49), ('сегодняшний', 50), ('того', 51), ('осознавать', 52), ('мелкие', 53), ('события', 54), ('слишком', 55), ('вдохновение', 56), ('для', 57), ('знать', 58), ('планы', 59), ('уверенность', 60), ('которая', 61), ('делает', 62), ('радость', 63), ('сегодняшние', 64), ('моей', 65), ('идёт', 66), ('приносит', 67), ('без', 68), ('спокойствие', 69), ('усталости', 70), ('простые', 71), ('тому', 72), ('жизни', 73), ('раздражение', 74), ('задачи', 75), ('создавали', 76), ('помогает', 77), ('вперёд', 78), ('только', 79), ('так', 80), ('много', 81), ('принимаю', 82), ('просто', 83), ('делаю', 84), ('есть', 85), ('зная', 86), ('обстоятельства', 87), ('чувствовать', 88), ('момент', 89), ('том', 90), ('новый', 91), ('думаю', 92), ('из', 93), ('уже', 94), ('сосредоточиться', 95), ('моё', 96), ('свою', 97), ('рушатся', 98), ('раздражения', 99), ('хаоса', 100), ('проблемы', 101), ('приходится', 102), ('радуюсь', 103), ('мой', 104), ('которое', 105), ('у', 106), ('чтобы', 107), ('действия', 108), ('создают', 109), ('превращаются', 110), ('был', 111), ('усталость', 112), ('понимая', 113), ('моменты', 114), ('если', 115), ('несмотря', 116), ('полон', 117), ('пути', 118), ('каждая', 119), ('ощущать', 120), ('становится', 121), ('действовать', 122), ('принимать', 123), ('решения', 124), ('мысли', 125), ('лучше', 126), ('а', 127), ('ожидания', 128), ('приносят', 129), ('словно', 130), ('неприятности', 131), ('требуют', 132), ('старания', 133), ('постепенно', 134), ('сердце', 135), ('благодарностью', 136), ('люди', 137), ('будто', 138), ('сделать', 139), ('внутренний', 140), ('своё', 141), ('замечать', 142), ('напоминаю', 143), ('видеть', 144), ('мелких', 145), ('необходимости', 146), ('ошибки', 147), ('результата', 148), ('постоянного', 149), ('мешают', 150), ('маленькие', 151), ('замечаю', 152), ('сильнее', 153), ('создавать', 154), ('моя', 155), ('который', 156), ('вины', 157), ('она', 158), ('более', 159), ('ещё', 160), ('приходит', 161), ('оставил', 162), ('благодарность', 163), ('любовью', 164), ('стать', 165), ('со', 166), ('ярче', 167), ('вспоминаю', 168), ('действительно', 169), ('свои', 170), ('её', 171), ('людей', 172), ('новые', 173), ('настроение', 174), ('верить', 175), ('наслаждаться', 176), ('силы', 177), ('поддержку', 178), ('времени', 179), ('его', 180), ('больше', 181), ('прожитый', 182), ('казался', 183), ('или', 184), ('время', 185), ('складываются', 186), ('весь', 187), ('постоянной', 188), ('накапливаются', 189), ('мелкими', 190), ('остаются', 191), ('специально', 192), ('быстрее', 193), ('медленно', 194), ('впустую', 195), ('планировал', 196), ('большое', 197), ('открывает', 198), ('мной', 199), ('возможности', 200), ('добро', 201), ('гармонию', 202), ('они', 203), ('своим', 204), ('ко', 205), ('благодарен', 206), ('будущее', 207), ('наполняет', 208), ('шаг', 209), ('моим', 210), ('людях', 211), ('доброту', 212), ('трудностями', 213), ('тепло', 214), ('других', 215), ('своими', 216), ('возможность', 217), ('гармонии', 218), ('нужно', 219), ('энергии', 220), ('моих', 221), ('усилий', 222), ('справиться', 223), ('бы', 224), ('сил', 225), ('ничего', 226), ('оставляя', 227), ('все', 228), ('успеваю', 229), ('сегодняшняя', 230), ('важных', 231), ('под', 232), ('неприятностей', 233), ('против', 234), ('проблем', 235), ('заботами', 236), ('радостью',  ...
# (600, 10) (600, 2)
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding_1 (Embedding)         │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ gru_2 (GRU)                     │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ gru_3 (GRU)                     │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ ?                      │   0 (unbuilt) │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 0 (0.00 B)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.5867 - loss: 0.6912
# Epoch 2/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8067 - loss: 0.6833
# Epoch 3/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9200 - loss: 0.6661
# Epoch 4/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9533 - loss: 0.6170
# Epoch 5/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9833 - loss: 0.4701
# Epoch 6/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9800 - loss: 0.2251
# Epoch 7/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9817 - loss: 0.0983
# Epoch 8/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9867 - loss: 0.0648
# Epoch 9/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9917 - loss: 0.0492
# Epoch 10/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9917 - loss: 0.0400
# Epoch 11/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9933 - loss: 0.0316
# Epoch 12/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9950 - loss: 0.0259
# Epoch 13/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9950 - loss: 0.0195
# Epoch 14/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9967 - loss: 0.0147
# Epoch 15/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9983 - loss: 0.0111
# Epoch 16/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9983 - loss: 0.0091
# Epoch 17/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 0.0060
# Epoch 18/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 0.0045
# Epoch 19/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 0.0035
# Epoch 20/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 0.0027
# Epoch 21/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 0.0022
# Epoch 22/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 0.0019
# Epoch 23/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 0.0016
# Epoch 24/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 0.0014
# Epoch 25/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 1.0000 - loss: 0.0012
# Epoch 26/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 0.0011
# Epoch 27/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 9.3852e-04
# Epoch 28/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 8.4904e-04
# Epoch 29/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 7.6440e-04
# Epoch 30/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 6.9442e-04
# Epoch 31/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 6.3405e-04
# Epoch 32/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 5.8416e-04
# Epoch 33/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 5.3694e-04
# Epoch 34/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 4.9596e-04
# Epoch 35/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 4.6281e-04
# Epoch 36/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 4.2903e-04
# Epoch 37/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 4.0139e-04
# Epoch 38/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 3.7606e-04
# Epoch 39/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 3.5262e-04
# Epoch 40/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 3.3221e-04
# Epoch 41/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 3.1386e-04
# Epoch 42/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 2.9569e-04
# Epoch 43/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 2.7961e-04
# Epoch 44/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 2.6589e-04
# Epoch 45/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 2.5261e-04
# Epoch 46/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 2.3920e-04
# Epoch 47/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 2.2732e-04
# Epoch 48/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 2.1692e-04
# Epoch 49/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 1.0000 - loss: 2.0729e-04
# Epoch 50/50
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 1.0000 - loss: 1.9847e-04
# ['я', 'не', 'за', 'это', 'же']
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 221ms/step
# [[8.7094588e-05 9.9991286e-01]]
# 1
